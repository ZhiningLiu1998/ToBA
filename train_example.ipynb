# %%
import numpy as np
import torch
from args import parse_args
from baselines import *
from data_utils import (
    get_data_stat,
    get_natural_imbalanced_split_data,
    get_step_imbalanced_split_data,
    load_data, 
)
from toba import TopoBalanceAugmenter
from trainer import NodeClassificationTrainer
from utils import get_model, get_device, print_centered

DATASET_SPACE = ["cora", "citeseer", "pubmed"]
MODE_SPACE = ["dummy", "pred", "topo"]
IMB_SPACE = {
    'step': [10, 20],
    'natural': [50, 100],
}

# %%
import sys
sys.argv = [""]
args = parse_args()

device = get_device(args.gpu_id)

print(
    f"Run experiment with\n"
    f"  - Datasets:        {DATASET_SPACE}\n"
    f"  - ToBA modes:      {MODE_SPACE}\n"
    f"  - Imbalance types: {IMB_SPACE}\n"
)

print_centered("Arguments", 40, fillchar="=")
kwlen = max([len(k) for k in args.__dict__.keys()]) + 1
for keys, values in args.__dict__.items():
    print(f"{keys:{kwlen}}: {values}")
print_centered("", 40, fillchar="=")

# run the experiment

for imb_type in IMB_SPACE.keys():  # loop over imbalance types
    
    for imb_ratio in IMB_SPACE[imb_type]: # loop over imbalance ratios
    
        print_centered(f"Imbalance Type [{imb_type.title()}] - Ratio [{imb_ratio}]", 80, fillchar="/", prefix="\n")
        
        for dataset in DATASET_SPACE:  # loop over datasets

            print_centered(f"Dataset [{dataset.title()}]", 80, fillchar="=", prefix="\n")

            args.imb_type = imb_type
            args.imb_ratio = imb_ratio
            args.dataset = dataset
            
            for toba_mode in MODE_SPACE:    # loop over ToBA modes
                
                print_centered(f"Dataset [{args.dataset.title()}] - {args.imb_type.title()}IR [{args.imb_ratio}] - ToBA [{toba_mode}]", 80, fillchar="=")

                best_results = []
                for i_run in range(1, args.n_runs + 1):
                    seed = args.seed + i_run

                    # load imbalanced data
                    data = load_data(args.dataset, to_device=device, verbose=args.debug)
                    if args.imb_type == "step":
                        data = get_step_imbalanced_split_data(
                            data, imbratio=args.imb_ratio, random_seed=seed, verbose=args.debug
                        )
                    elif args.imb_type == "natural":
                        data = get_natural_imbalanced_split_data(
                            data, imbratio=args.imb_ratio, random_seed=seed, verbose=args.debug
                        )
                    else:
                        raise ValueError(
                            f"imb_type must be one of ['step', 'natural'], got {args.imb_type}."
                        )
                    data = get_data_stat(data, store_in_data=True, verbose=args.debug)

                    # initialize model
                    model = get_model(
                        gnn_arch=args.gnn_arch,
                        feat_dim=data.n_feat,
                        hid_dim=args.hid_dim,
                        out_dim=data.n_class,
                        n_layer=args.n_layer,
                        imb_handling=args.imb_handling,
                        device=device,
                    )
                    # toba augmenter
                    augmenter = TopoBalanceAugmenter(mode=toba_mode, random_state=seed)
                    # trainer
                    trainer = NodeClassificationTrainer(
                        model=model,
                        data=data,
                        device=device,
                        augmenter=augmenter,  # ToBA augmentation, to disable, set augmenter=None
                        learning_rate=args.lr,
                        weight_decay=args.weight_decay,
                        train_epoch=args.epochs,
                        early_stop_patience=args.early_stop,
                        eval_freq=1,
                        verbose_freq=None,
                        enable_tqdm=args.tqdm,
                        random_state=seed,
                    )
                    # train the GNN with ToBA augmentation
                    best_model = trainer.train()
                    # print best results
                    trainer.print_best_results()
                    # save best results
                    best_results.append(trainer.best_eval_results)

                # print the average performance of the best model
                info = f"Avg Test Performance ({args.n_runs} runs): "
                for metric in trainer.eval_metrics.keys():
                    scores = np.array(
                        [
                            best_results[i][metric]["test"] * 100
                            for i in range(len(best_results))
                        ]
                    )
                    info += f" | {metric.upper()}: {scores.mean():.2f} ± {scores.std()/(len(scores)**0.5):.2f}"
                print(info)
# Out:
# Now using GPU #3: Tesla V100-SXM2-32GB
# Run experiment with
#   - Datasets:        ['cora', 'citeseer', 'pubmed']
#   - ToBA modes:      ['dummy', 'pred', 'topo']
#   - Imbalance types: {'step': [10, 20], 'natural': [50, 100]}
#
# ============== Arguments ==============
# gpu_id       : 3
# seed         : 42
# n_runs       : 5
# debug        : False
# dataset      : cora
# imb_type     : step
# imb_ratio    : 10
# gnn_arch     : GCN
# n_layer      : 3
# hid_dim      : 256
# lr           : 0.01
# weight_decay : 0.0005
# epochs       : 2000
# early_stop   : 200
# tqdm         : False
# imb_handling : None
# toba_mode    : all
# ========================================
#
# ////////////////////// Imbalance Type [Step] - Ratio [10] //////////////////////
#
# ================================ Dataset [Cora] ================================
# ================= Dataset [Cora] - StepIR [10] - ToBA [dummy] =================
# Best Epoch:   97 | train/val/test | ACC: 100.0/67.20/67.50 | BACC: 100.0/61.93/60.55 | MACRO-F1: 100.0/59.65/59.29 | upd/aug time: 5.45/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   67 | train/val/test | ACC: 100.0/65.20/65.00 | BACC: 100.0/60.04/57.70 | MACRO-F1: 100.0/57.21/55.09 | upd/aug time: 4.41/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  131 | train/val/test | ACC: 100.0/66.80/67.90 | BACC: 100.0/63.78/61.71 | MACRO-F1: 100.0/62.26/60.08 | upd/aug time: 3.95/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   60 | train/val/test | ACC: 100.0/66.40/66.30 | BACC: 100.0/61.60/60.74 | MACRO-F1: 100.0/58.04/59.09 | upd/aug time: 3.50/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  151 | train/val/test | ACC: 100.0/63.20/63.70 | BACC: 100.0/57.82/55.99 | MACRO-F1: 100.0/53.30/51.88 | upd/aug time: 3.48/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 66.08 ± 0.70 | BACC: 59.34 ± 0.96 | MACRO-F1: 57.09 ± 1.40
# ================== Dataset [Cora] - StepIR [10] - ToBA [pred] ==================
# Best Epoch:  316 | train/val/test | ACC: 100.0/67.20/66.80 | BACC: 100.0/65.12/63.64 | MACRO-F1: 100.0/63.67/62.38 | upd/aug time: 3.46/3.99ms | node/edge ratio: 100.26/102.95%
# Best Epoch:  203 | train/val/test | ACC: 100.0/70.20/67.90 | BACC: 100.0/71.29/67.67 | MACRO-F1: 100.0/69.41/65.48 | upd/aug time: 3.85/4.43ms | node/edge ratio: 100.26/103.20%
# Best Epoch:  311 | train/val/test | ACC: 100.0/71.60/70.80 | BACC: 100.0/69.10/67.49 | MACRO-F1: 100.0/68.13/66.82 | upd/aug time: 3.65/4.20ms | node/edge ratio: 100.26/103.00%
# Best Epoch:  341 | train/val/test | ACC: 100.0/69.00/67.80 | BACC: 100.0/66.32/64.38 | MACRO-F1: 100.0/63.86/62.65 | upd/aug time: 3.35/3.87ms | node/edge ratio: 100.26/103.13%
# Best Epoch:  156 | train/val/test | ACC: 100.0/66.00/66.40 | BACC: 100.0/61.97/59.46 | MACRO-F1: 100.0/59.46/57.35 | upd/aug time: 3.28/3.77ms | node/edge ratio: 100.26/103.22%
# Avg Test Performance (5 runs):  | ACC: 67.94 ± 0.69 | BACC: 64.53 ± 1.34 | MACRO-F1: 62.94 ± 1.46
# ================== Dataset [Cora] - StepIR [10] - ToBA [topo] ==================
# Best Epoch:   72 | train/val/test | ACC: 100.0/72.00/72.20 | BACC: 100.0/69.65/68.93 | MACRO-F1: 100.0/66.88/67.10 | upd/aug time: 3.32/4.36ms | node/edge ratio: 100.26/101.44%
# Best Epoch:  204 | train/val/test | ACC: 100.0/72.40/70.10 | BACC: 100.0/72.79/69.91 | MACRO-F1: 100.0/70.28/67.76 | upd/aug time: 3.26/4.32ms | node/edge ratio: 100.26/101.73%
# Best Epoch:  155 | train/val/test | ACC: 100.0/74.00/73.60 | BACC: 100.0/74.38/72.50 | MACRO-F1: 100.0/71.37/70.73 | upd/aug time: 3.58/4.76ms | node/edge ratio: 100.26/101.55%
# Best Epoch:   71 | train/val/test | ACC: 100.0/72.40/72.10 | BACC: 100.0/69.50/67.75 | MACRO-F1: 100.0/68.11/66.80 | upd/aug time: 3.48/4.64ms | node/edge ratio: 100.26/101.52%
# Best Epoch:   77 | train/val/test | ACC: 100.0/76.20/77.60 | BACC: 100.0/78.03/77.92 | MACRO-F1: 100.0/75.06/76.42 | upd/aug time: 3.32/4.39ms | node/edge ratio: 100.26/101.60%
# Avg Test Performance (5 runs):  | ACC: 73.12 ± 1.12 | BACC: 71.40 ± 1.62 | MACRO-F1: 69.76 ± 1.61
#
# ============================== Dataset [Citeseer] ==============================
# =============== Dataset [Citeseer] - StepIR [10] - ToBA [dummy] ===============
# Best Epoch:   57 | train/val/test | ACC: 100.0/45.20/40.30 | BACC: 100.0/42.27/41.85 | MACRO-F1: 100.0/33.57/32.96 | upd/aug time: 3.63/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  103 | train/val/test | ACC: 100.0/48.20/42.60 | BACC: 100.0/45.69/43.69 | MACRO-F1: 100.0/39.97/37.40 | upd/aug time: 3.67/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   85 | train/val/test | ACC: 100.0/37.20/34.50 | BACC: 100.0/35.72/36.41 | MACRO-F1: 100.0/28.07/27.64 | upd/aug time: 3.57/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   66 | train/val/test | ACC: 100.0/38.40/34.20 | BACC: 100.0/36.54/36.79 | MACRO-F1: 100.0/28.47/26.82 | upd/aug time: 3.55/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   13 | train/val/test | ACC: 83.33/34.40/30.90 | BACC: 45.83/34.60/33.87 | MACRO-F1: 43.66/22.03/21.04 | upd/aug time: 3.55/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 36.50 ± 1.92 | BACC: 38.52 ± 1.64 | MACRO-F1: 29.17 ± 2.50
# ================ Dataset [Citeseer] - StepIR [10] - ToBA [pred] ================
# Best Epoch:  293 | train/val/test | ACC: 98.48/63.60/62.80 | BACC: 99.17/59.66/59.79 | MACRO-F1: 99.17/59.31/59.62 | upd/aug time: 3.49/3.99ms | node/edge ratio: 100.18/104.03%
# Best Epoch:  322 | train/val/test | ACC: 100.0/52.20/51.60 | BACC: 100.0/46.56/47.53 | MACRO-F1: 100.0/44.73/44.83 | upd/aug time: 3.48/4.01ms | node/edge ratio: 100.18/103.01%
# Best Epoch:  213 | train/val/test | ACC: 100.0/62.80/62.60 | BACC: 100.0/59.89/60.41 | MACRO-F1: 100.0/58.77/59.95 | upd/aug time: 3.50/3.99ms | node/edge ratio: 100.18/103.80%
# Best Epoch:  132 | train/val/test | ACC: 100.0/44.60/38.20 | BACC: 100.0/42.73/38.01 | MACRO-F1: 100.0/41.88/36.76 | upd/aug time: 3.49/4.00ms | node/edge ratio: 100.18/103.73%
# Best Epoch:  156 | train/val/test | ACC: 100.0/59.60/58.40 | BACC: 100.0/56.14/55.65 | MACRO-F1: 100.0/55.24/54.96 | upd/aug time: 3.49/4.00ms | node/edge ratio: 100.18/104.00%
# Avg Test Performance (5 runs):  | ACC: 54.72 ± 4.12 | BACC: 52.28 ± 3.79 | MACRO-F1: 51.22 ± 4.05
# ================ Dataset [Citeseer] - StepIR [10] - ToBA [topo] ================
# Best Epoch:  157 | train/val/test | ACC: 100.0/64.20/62.90 | BACC: 100.0/60.34/59.72 | MACRO-F1: 100.0/59.56/59.31 | upd/aug time: 3.53/4.83ms | node/edge ratio: 100.18/101.03%
# Best Epoch:   73 | train/val/test | ACC: 96.97/56.80/55.30 | BACC: 98.33/51.08/51.65 | MACRO-F1: 98.35/48.23/47.97 | upd/aug time: 3.97/5.35ms | node/edge ratio: 100.18/100.90%
# Best Epoch:  130 | train/val/test | ACC: 100.0/64.00/64.30 | BACC: 100.0/61.34/61.63 | MACRO-F1: 100.0/59.70/60.94 | upd/aug time: 4.01/5.38ms | node/edge ratio: 100.18/100.93%
# Best Epoch:  111 | train/val/test | ACC: 100.0/63.40/61.70 | BACC: 100.0/59.49/58.87 | MACRO-F1: 100.0/59.04/58.74 | upd/aug time: 4.07/5.39ms | node/edge ratio: 100.18/100.93%
# Best Epoch:  236 | train/val/test | ACC: 100.0/50.80/46.70 | BACC: 100.0/50.73/49.48 | MACRO-F1: 100.0/44.44/43.11 | upd/aug time: 4.08/5.37ms | node/edge ratio: 100.18/101.15%
# Avg Test Performance (5 runs):  | ACC: 58.18 ± 2.91 | BACC: 56.27 ± 2.14 | MACRO-F1: 54.01 ± 3.19
#
# =============================== Dataset [Pubmed] ===============================
# ================ Dataset [Pubmed] - StepIR [10] - ToBA [dummy] ================
# Best Epoch:   60 | train/val/test | ACC: 100.0/57.00/56.00 | BACC: 100.0/64.17/61.63 | MACRO-F1: 100.0/50.42/48.98 | upd/aug time: 6.31/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   67 | train/val/test | ACC: 100.0/66.20/66.20 | BACC: 100.0/71.01/69.15 | MACRO-F1: 100.0/64.89/64.67 | upd/aug time: 6.11/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  100 | train/val/test | ACC: 100.0/59.60/58.50 | BACC: 100.0/66.70/64.53 | MACRO-F1: 100.0/55.09/53.49 | upd/aug time: 6.13/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   95 | train/val/test | ACC: 100.0/70.20/64.00 | BACC: 100.0/75.37/69.35 | MACRO-F1: 100.0/68.57/61.28 | upd/aug time: 6.27/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  213 | train/val/test | ACC: 100.0/56.00/53.70 | BACC: 100.0/63.73/59.85 | MACRO-F1: 100.0/48.42/44.99 | upd/aug time: 6.01/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 59.68 ± 2.12 | BACC: 64.90 ± 1.72 | MACRO-F1: 54.68 ± 3.29
# ================= Dataset [Pubmed] - StepIR [10] - ToBA [pred] =================
# Best Epoch:  121 | train/val/test | ACC: 100.0/69.40/66.70 | BACC: 100.0/70.13/66.45 | MACRO-F1: 100.0/69.23/66.03 | upd/aug time: 6.24/6.20ms | node/edge ratio: 100.02/103.27%
# Best Epoch:  200 | train/val/test | ACC: 97.62/72.60/69.70 | BACC: 98.33/71.98/68.58 | MACRO-F1: 92.48/72.88/69.76 | upd/aug time: 6.29/6.22ms | node/edge ratio: 100.02/103.04%
# Best Epoch:   81 | train/val/test | ACC: 97.62/72.80/68.60 | BACC: 98.33/73.41/68.93 | MACRO-F1: 92.48/73.03/68.24 | upd/aug time: 6.25/6.19ms | node/edge ratio: 100.02/103.08%
# Best Epoch:  225 | train/val/test | ACC: 100.0/71.40/67.90 | BACC: 100.0/71.47/67.34 | MACRO-F1: 100.0/72.44/68.23 | upd/aug time: 6.11/6.05ms | node/edge ratio: 100.02/103.05%
# Best Epoch:   95 | train/val/test | ACC: 100.0/69.00/63.10 | BACC: 100.0/70.50/64.77 | MACRO-F1: 100.0/69.56/63.73 | upd/aug time: 6.31/6.29ms | node/edge ratio: 100.02/103.38%
# Avg Test Performance (5 runs):  | ACC: 67.20 ± 1.02 | BACC: 67.21 ± 0.68 | MACRO-F1: 67.20 ± 0.94
# ================= Dataset [Pubmed] - StepIR [10] - ToBA [topo] =================
# Best Epoch:   53 | train/val/test | ACC: 100.0/58.40/58.60 | BACC: 100.0/63.31/62.41 | MACRO-F1: 100.0/55.34/55.48 | upd/aug time: 6.35/44.98ms | node/edge ratio: 100.02/101.17%
# Best Epoch:  116 | train/val/test | ACC: 97.62/64.60/65.50 | BACC: 98.33/66.15/65.88 | MACRO-F1: 98.33/62.39/62.66 | upd/aug time: 6.32/45.04ms | node/edge ratio: 100.02/101.45%
# Best Epoch:  111 | train/val/test | ACC: 100.0/68.00/67.50 | BACC: 100.0/71.14/68.69 | MACRO-F1: 100.0/67.25/66.44 | upd/aug time: 6.17/44.89ms | node/edge ratio: 100.02/101.44%
# Best Epoch:   72 | train/val/test | ACC: 100.0/76.00/71.30 | BACC: 100.0/77.46/72.64 | MACRO-F1: 100.0/74.86/69.90 | upd/aug time: 6.16/44.73ms | node/edge ratio: 100.02/101.36%
# Best Epoch:  340 | train/val/test | ACC: 100.0/69.40/65.10 | BACC: 100.0/73.53/69.05 | MACRO-F1: 100.0/69.12/63.99 | upd/aug time: 6.36/44.88ms | node/edge ratio: 100.02/101.40%
# Avg Test Performance (5 runs):  | ACC: 65.60 ± 1.85 | BACC: 67.74 ± 1.53 | MACRO-F1: 63.69 ± 2.14
#
# ////////////////////// Imbalance Type [Step] - Ratio [20] //////////////////////
#
# ================================ Dataset [Cora] ================================
# ================= Dataset [Cora] - StepIR [20] - ToBA [dummy] =================
# Best Epoch:  109 | train/val/test | ACC: 100.0/63.20/64.30 | BACC: 100.0/59.18/57.26 | MACRO-F1: 100.0/54.00/53.17 | upd/aug time: 3.95/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  243 | train/val/test | ACC: 100.0/61.60/61.20 | BACC: 100.0/54.18/51.87 | MACRO-F1: 100.0/48.93/46.44 | upd/aug time: 3.92/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  193 | train/val/test | ACC: 100.0/65.80/66.20 | BACC: 100.0/62.16/59.82 | MACRO-F1: 100.0/59.74/57.35 | upd/aug time: 3.98/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   89 | train/val/test | ACC: 100.0/59.80/61.30 | BACC: 100.0/53.72/52.78 | MACRO-F1: 100.0/47.01/47.33 | upd/aug time: 3.96/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   89 | train/val/test | ACC: 100.0/60.80/60.50 | BACC: 100.0/53.54/51.65 | MACRO-F1: 100.0/47.07/44.61 | upd/aug time: 3.36/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 62.70 ± 0.98 | BACC: 54.68 ± 1.47 | MACRO-F1: 49.78 ± 2.12
# ================== Dataset [Cora] - StepIR [20] - ToBA [pred] ==================
# Best Epoch:  399 | train/val/test | ACC: 100.0/68.40/69.10 | BACC: 100.0/65.78/65.08 | MACRO-F1: 100.0/63.33/63.01 | upd/aug time: 3.82/4.36ms | node/edge ratio: 100.26/103.04%
# Best Epoch:  230 | train/val/test | ACC: 100.0/62.20/62.50 | BACC: 100.0/61.54/59.65 | MACRO-F1: 100.0/59.03/57.63 | upd/aug time: 3.81/4.38ms | node/edge ratio: 100.26/103.16%
# Best Epoch:  275 | train/val/test | ACC: 100.0/71.00/72.50 | BACC: 100.0/70.82/71.22 | MACRO-F1: 100.0/68.74/69.75 | upd/aug time: 3.83/4.39ms | node/edge ratio: 100.26/102.88%
# Best Epoch:  205 | train/val/test | ACC: 100.0/65.00/68.70 | BACC: 100.0/60.98/63.40 | MACRO-F1: 100.0/59.18/62.55 | upd/aug time: 3.68/4.19ms | node/edge ratio: 100.26/103.34%
# Best Epoch:  430 | train/val/test | ACC: 100.0/60.40/61.70 | BACC: 100.0/54.44/54.29 | MACRO-F1: 100.0/51.68/51.87 | upd/aug time: 3.70/4.25ms | node/edge ratio: 100.26/103.49%
# Avg Test Performance (5 runs):  | ACC: 66.90 ± 1.85 | BACC: 62.73 ± 2.52 | MACRO-F1: 60.96 ± 2.67
# ================== Dataset [Cora] - StepIR [20] - ToBA [topo] ==================
# Best Epoch:  167 | train/val/test | ACC: 100.0/70.80/70.50 | BACC: 100.0/68.23/67.67 | MACRO-F1: 100.0/65.53/65.32 | upd/aug time: 3.40/4.46ms | node/edge ratio: 100.26/101.45%
# Best Epoch:  153 | train/val/test | ACC: 100.0/76.20/76.20 | BACC: 100.0/75.41/75.08 | MACRO-F1: 100.0/73.98/74.20 | upd/aug time: 3.34/4.36ms | node/edge ratio: 100.26/101.60%
# Best Epoch:  163 | train/val/test | ACC: 100.0/76.40/75.70 | BACC: 100.0/76.87/74.98 | MACRO-F1: 100.0/74.65/73.45 | upd/aug time: 3.78/5.04ms | node/edge ratio: 100.26/101.68%
# Best Epoch:  257 | train/val/test | ACC: 100.0/70.40/69.90 | BACC: 100.0/69.36/68.52 | MACRO-F1: 100.0/66.16/66.41 | upd/aug time: 3.64/4.81ms | node/edge ratio: 100.26/101.58%
# Best Epoch:  118 | train/val/test | ACC: 100.0/67.40/68.70 | BACC: 100.0/63.79/63.11 | MACRO-F1: 100.0/58.63/58.34 | upd/aug time: 3.27/4.33ms | node/edge ratio: 100.26/101.64%
# Avg Test Performance (5 runs):  | ACC: 72.20 ± 1.40 | BACC: 69.87 ± 2.06 | MACRO-F1: 67.54 ± 2.61
#
# ============================== Dataset [Citeseer] ==============================
# =============== Dataset [Citeseer] - StepIR [20] - ToBA [dummy] ===============
# Best Epoch:   95 | train/val/test | ACC: 100.0/35.20/32.40 | BACC: 100.0/33.69/34.89 | MACRO-F1: 100.0/24.58/24.49 | upd/aug time: 3.62/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  188 | train/val/test | ACC: 100.0/38.20/33.20 | BACC: 100.0/37.44/35.35 | MACRO-F1: 100.0/29.69/26.51 | upd/aug time: 3.70/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  114 | train/val/test | ACC: 100.0/33.40/30.20 | BACC: 100.0/32.80/32.53 | MACRO-F1: 100.0/21.92/20.67 | upd/aug time: 3.97/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   16 | train/val/test | ACC: 90.48/35.00/32.90 | BACC: 47.50/34.34/34.70 | MACRO-F1: 46.39/21.34/21.25 | upd/aug time: 3.57/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   16 | train/val/test | ACC: 88.89/34.40/31.80 | BACC: 46.67/34.95/35.07 | MACRO-F1: 45.50/22.01/21.49 | upd/aug time: 3.68/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 32.10 ± 0.47 | BACC: 34.51 ± 0.45 | MACRO-F1: 22.88 ± 1.00
# ================ Dataset [Citeseer] - StepIR [20] - ToBA [pred] ================
# Best Epoch:  282 | train/val/test | ACC: 100.0/60.20/61.30 | BACC: 100.0/58.33/59.53 | MACRO-F1: 100.0/57.13/59.16 | upd/aug time: 3.61/4.06ms | node/edge ratio: 100.18/104.79%
# Best Epoch:  483 | train/val/test | ACC: 100.0/53.20/51.00 | BACC: 100.0/47.85/48.36 | MACRO-F1: 100.0/45.80/45.38 | upd/aug time: 3.61/4.17ms | node/edge ratio: 100.18/104.35%
# Best Epoch:  182 | train/val/test | ACC: 100.0/61.20/60.90 | BACC: 100.0/58.25/58.70 | MACRO-F1: 100.0/57.58/58.31 | upd/aug time: 3.47/3.96ms | node/edge ratio: 100.18/104.72%
# Best Epoch:  685 | train/val/test | ACC: 100.0/59.00/55.80 | BACC: 100.0/57.14/55.38 | MACRO-F1: 100.0/55.01/54.09 | upd/aug time: 3.56/4.00ms | node/edge ratio: 100.18/104.16%
# Best Epoch:  200 | train/val/test | ACC: 100.0/48.60/53.50 | BACC: 100.0/46.22/51.32 | MACRO-F1: 100.0/45.95/50.88 | upd/aug time: 4.07/4.70ms | node/edge ratio: 100.18/104.22%
# Avg Test Performance (5 runs):  | ACC: 56.50 ± 1.81 | BACC: 54.66 ± 1.91 | MACRO-F1: 53.56 ± 2.27
# ================ Dataset [Citeseer] - StepIR [20] - ToBA [topo] ================
# Best Epoch:  121 | train/val/test | ACC: 100.0/63.60/62.00 | BACC: 100.0/60.13/59.02 | MACRO-F1: 100.0/59.45/58.80 | upd/aug time: 3.70/4.77ms | node/edge ratio: 100.18/100.97%
# Best Epoch:  260 | train/val/test | ACC: 100.0/53.00/51.70 | BACC: 100.0/48.87/48.88 | MACRO-F1: 100.0/47.60/47.56 | upd/aug time: 4.06/5.43ms | node/edge ratio: 100.18/101.24%
# Best Epoch:  291 | train/val/test | ACC: 100.0/55.20/57.90 | BACC: 100.0/53.53/55.21 | MACRO-F1: 100.0/52.45/54.84 | upd/aug time: 4.12/5.49ms | node/edge ratio: 100.18/101.06%
# Best Epoch:  256 | train/val/test | ACC: 100.0/61.40/60.00 | BACC: 100.0/58.55/57.31 | MACRO-F1: 100.0/57.78/57.13 | upd/aug time: 4.07/5.49ms | node/edge ratio: 100.18/100.92%
# Best Epoch:  133 | train/val/test | ACC: 100.0/42.40/41.40 | BACC: 100.0/46.11/45.35 | MACRO-F1: 100.0/33.73/33.67 | upd/aug time: 4.07/5.51ms | node/edge ratio: 100.18/101.40%
# Avg Test Performance (5 runs):  | ACC: 54.60 ± 3.33 | BACC: 53.16 ± 2.33 | MACRO-F1: 50.40 ± 4.12
#
# =============================== Dataset [Pubmed] ===============================
# ================ Dataset [Pubmed] - StepIR [20] - ToBA [dummy] ================
# Best Epoch:   99 | train/val/test | ACC: 100.0/56.00/54.40 | BACC: 100.0/62.88/59.69 | MACRO-F1: 100.0/48.95/46.62 | upd/aug time: 6.12/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  182 | train/val/test | ACC: 100.0/59.80/58.10 | BACC: 100.0/66.09/62.72 | MACRO-F1: 100.0/55.56/53.17 | upd/aug time: 6.23/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  147 | train/val/test | ACC: 100.0/57.40/55.90 | BACC: 100.0/64.69/61.75 | MACRO-F1: 100.0/50.67/48.59 | upd/aug time: 6.16/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  196 | train/val/test | ACC: 100.0/56.40/54.00 | BACC: 100.0/64.05/60.62 | MACRO-F1: 100.0/48.82/45.61 | upd/aug time: 6.26/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  214 | train/val/test | ACC: 100.0/56.00/54.10 | BACC: 100.0/63.75/60.38 | MACRO-F1: 100.0/48.04/45.23 | upd/aug time: 6.23/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 55.30 ± 0.70 | BACC: 61.03 ± 0.48 | MACRO-F1: 47.85 ± 1.30
# ================= Dataset [Pubmed] - StepIR [20] - ToBA [pred] =================
# Best Epoch:  225 | train/val/test | ACC: 100.0/67.60/67.50 | BACC: 100.0/68.99/68.00 | MACRO-F1: 100.0/67.47/67.24 | upd/aug time: 6.25/6.28ms | node/edge ratio: 100.02/103.48%
# Best Epoch:  308 | train/val/test | ACC: 100.0/67.20/66.80 | BACC: 100.0/68.50/66.92 | MACRO-F1: 100.0/66.51/65.86 | upd/aug time: 5.72/5.71ms | node/edge ratio: 100.02/103.50%
# Best Epoch:  174 | train/val/test | ACC: 100.0/68.80/65.70 | BACC: 100.0/70.24/66.24 | MACRO-F1: 100.0/68.89/65.48 | upd/aug time: 5.74/5.73ms | node/edge ratio: 100.02/103.65%
# Best Epoch:  158 | train/val/test | ACC: 100.0/60.80/57.50 | BACC: 100.0/65.32/61.60 | MACRO-F1: 100.0/59.95/55.63 | upd/aug time: 5.74/5.75ms | node/edge ratio: 100.02/103.80%
# Best Epoch:  109 | train/val/test | ACC: 100.0/67.00/67.30 | BACC: 100.0/69.34/68.25 | MACRO-F1: 100.0/65.81/65.52 | upd/aug time: 5.87/5.73ms | node/edge ratio: 100.02/103.63%
# Avg Test Performance (5 runs):  | ACC: 64.96 ± 1.69 | BACC: 66.20 ± 1.08 | MACRO-F1: 63.95 ± 1.88
# ================= Dataset [Pubmed] - StepIR [20] - ToBA [topo] =================
# Best Epoch:   65 | train/val/test | ACC: 97.56/67.00/66.40 | BACC: 98.33/68.98/66.53 | MACRO-F1: 88.03/66.59/65.35 | upd/aug time: 5.74/44.53ms | node/edge ratio: 100.02/101.25%
# Best Epoch:   70 | train/val/test | ACC: 97.56/65.60/64.10 | BACC: 98.33/68.06/64.42 | MACRO-F1: 88.03/64.96/62.55 | upd/aug time: 5.70/44.27ms | node/edge ratio: 100.02/101.36%
# Best Epoch:   80 | train/val/test | ACC: 100.0/62.80/63.20 | BACC: 100.0/64.23/62.65 | MACRO-F1: 100.0/60.92/60.90 | upd/aug time: 6.08/44.71ms | node/edge ratio: 100.02/101.31%
# Best Epoch:  145 | train/val/test | ACC: 100.0/75.20/70.80 | BACC: 100.0/77.55/72.65 | MACRO-F1: 100.0/74.41/69.66 | upd/aug time: 6.21/44.87ms | node/edge ratio: 100.02/101.28%
# Best Epoch:   76 | train/val/test | ACC: 100.0/57.40/54.10 | BACC: 100.0/60.79/55.41 | MACRO-F1: 100.0/54.96/49.72 | upd/aug time: 6.16/44.96ms | node/edge ratio: 100.02/101.08%
# Avg Test Performance (5 runs):  | ACC: 63.72 ± 2.45 | BACC: 64.33 ± 2.50 | MACRO-F1: 61.64 ± 2.98
#
# //////////////////// Imbalance Type [Natural] - Ratio [50] ////////////////////
#
# ================================ Dataset [Cora] ================================
# ================ Dataset [Cora] - NaturalIR [50] - ToBA [dummy] ================
# Best Epoch:  179 | train/val/test | ACC: 100.0/70.35/67.20 | BACC: 100.0/58.68/55.43 | MACRO-F1: 100.0/56.69/52.78 | upd/aug time: 3.29/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  276 | train/val/test | ACC: 100.0/75.73/75.40 | BACC: 100.0/70.25/69.38 | MACRO-F1: 100.0/70.14/69.62 | upd/aug time: 3.41/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   68 | train/val/test | ACC: 99.01/63.29/62.22 | BACC: 85.71/50.84/49.72 | MACRO-F1: 80.95/48.90/47.37 | upd/aug time: 3.48/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  267 | train/val/test | ACC: 100.0/71.51/72.95 | BACC: 100.0/62.22/63.93 | MACRO-F1: 100.0/61.99/63.80 | upd/aug time: 3.32/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  240 | train/val/test | ACC: 100.0/69.74/71.03 | BACC: 100.0/59.89/60.71 | MACRO-F1: 100.0/60.21/60.41 | upd/aug time: 3.57/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 69.76 ± 2.07 | BACC: 59.84 ± 3.04 | MACRO-F1: 58.80 ± 3.53
# ================ Dataset [Cora] - NaturalIR [50] - ToBA [pred] ================
# Best Epoch:  207 | train/val/test | ACC: 100.0/73.89/71.34 | BACC: 100.0/68.11/66.30 | MACRO-F1: 100.0/67.89/66.32 | upd/aug time: 3.48/3.83ms | node/edge ratio: 100.26/101.67%
# Best Epoch:  128 | train/val/test | ACC: 98.02/70.58/69.89 | BACC: 85.16/63.19/61.89 | MACRO-F1: 84.34/62.75/61.61 | upd/aug time: 3.90/4.55ms | node/edge ratio: 100.26/101.50%
# Best Epoch:  223 | train/val/test | ACC: 100.0/65.67/64.29 | BACC: 100.0/61.47/59.29 | MACRO-F1: 100.0/59.70/57.55 | upd/aug time: 3.62/4.17ms | node/edge ratio: 100.26/101.85%
# Best Epoch:  183 | train/val/test | ACC: 99.01/71.43/73.49 | BACC: 99.45/68.28/69.96 | MACRO-F1: 99.58/67.29/68.79 | upd/aug time: 3.86/4.56ms | node/edge ratio: 100.26/101.70%
# Best Epoch:  224 | train/val/test | ACC: 100.0/74.04/75.02 | BACC: 100.0/71.62/70.46 | MACRO-F1: 100.0/71.39/70.42 | upd/aug time: 3.58/4.11ms | node/edge ratio: 100.26/101.62%
# Avg Test Performance (5 runs):  | ACC: 70.80 ± 1.66 | BACC: 65.58 ± 1.97 | MACRO-F1: 64.94 ± 2.12
# ================ Dataset [Cora] - NaturalIR [50] - ToBA [topo] ================
# Best Epoch:  104 | train/val/test | ACC: 100.0/73.58/72.18 | BACC: 100.0/64.72/63.49 | MACRO-F1: 100.0/61.62/60.45 | upd/aug time: 4.13/5.11ms | node/edge ratio: 100.26/101.05%
# Best Epoch:  219 | train/val/test | ACC: 100.0/76.73/74.79 | BACC: 100.0/72.16/69.42 | MACRO-F1: 100.0/71.34/69.36 | upd/aug time: 3.56/4.44ms | node/edge ratio: 100.26/100.77%
# Best Epoch:  107 | train/val/test | ACC: 99.01/67.74/68.58 | BACC: 99.45/59.31/59.83 | MACRO-F1: 99.58/55.43/56.22 | upd/aug time: 3.26/4.27ms | node/edge ratio: 100.26/101.31%
# Best Epoch:  196 | train/val/test | ACC: 99.01/74.73/73.10 | BACC: 99.45/68.19/66.70 | MACRO-F1: 99.58/66.41/64.23 | upd/aug time: 3.21/4.28ms | node/edge ratio: 100.26/101.11%
# Best Epoch:  121 | train/val/test | ACC: 100.0/73.58/74.18 | BACC: 100.0/66.90/65.74 | MACRO-F1: 100.0/63.85/62.71 | upd/aug time: 3.55/4.59ms | node/edge ratio: 100.26/100.94%
# Avg Test Performance (5 runs):  | ACC: 72.57 ± 0.98 | BACC: 65.04 ± 1.44 | MACRO-F1: 62.59 ± 1.94
#
# ============================== Dataset [Citeseer] ==============================
# ============== Dataset [Citeseer] - NaturalIR [50] - ToBA [dummy] ==============
# Best Epoch:   90 | train/val/test | ACC: 98.88/54.70/55.80 | BACC: 83.33/48.05/49.31 | MACRO-F1: 81.48/40.93/42.39 | upd/aug time: 3.59/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  202 | train/val/test | ACC: 100.0/57.29/55.93 | BACC: 100.0/51.72/50.41 | MACRO-F1: 100.0/46.49/45.45 | upd/aug time: 3.57/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  293 | train/val/test | ACC: 100.0/52.60/51.11 | BACC: 100.0/46.01/44.72 | MACRO-F1: 100.0/39.17/38.07 | upd/aug time: 3.86/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  175 | train/val/test | ACC: 100.0/53.40/55.06 | BACC: 100.0/46.75/48.28 | MACRO-F1: 100.0/40.37/42.41 | upd/aug time: 3.65/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  146 | train/val/test | ACC: 100.0/49.01/49.38 | BACC: 100.0/42.20/42.61 | MACRO-F1: 100.0/32.24/32.50 | upd/aug time: 3.84/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 53.46 ± 1.20 | BACC: 47.07 ± 1.31 | MACRO-F1: 40.16 ± 2.01
# ============== Dataset [Citeseer] - NaturalIR [50] - ToBA [pred] ==============
# Best Epoch:  184 | train/val/test | ACC: 100.0/61.87/58.15 | BACC: 100.0/56.82/53.09 | MACRO-F1: 100.0/55.72/52.23 | upd/aug time: 3.84/4.39ms | node/edge ratio: 100.18/101.83%
# Best Epoch:  346 | train/val/test | ACC: 100.0/53.52/50.31 | BACC: 100.0/49.78/46.63 | MACRO-F1: 100.0/49.25/45.85 | upd/aug time: 3.51/3.95ms | node/edge ratio: 100.18/101.73%
# Best Epoch:  285 | train/val/test | ACC: 100.0/59.39/58.70 | BACC: 100.0/53.71/53.22 | MACRO-F1: 100.0/52.05/51.69 | upd/aug time: 3.50/4.00ms | node/edge ratio: 100.18/102.18%
# Best Epoch:   90 | train/val/test | ACC: 100.0/58.22/56.85 | BACC: 100.0/53.28/52.17 | MACRO-F1: 100.0/52.00/51.01 | upd/aug time: 3.47/3.99ms | node/edge ratio: 100.18/101.88%
# Best Epoch:  289 | train/val/test | ACC: 100.0/58.28/56.91 | BACC: 100.0/54.02/52.39 | MACRO-F1: 100.0/53.65/51.90 | upd/aug time: 3.79/4.29ms | node/edge ratio: 100.18/101.75%
# Avg Test Performance (5 runs):  | ACC: 56.19 ± 1.35 | BACC: 51.50 ± 1.10 | MACRO-F1: 50.54 ± 1.06
# ============== Dataset [Citeseer] - NaturalIR [50] - ToBA [topo] ==============
# Best Epoch:  125 | train/val/test | ACC: 100.0/66.63/64.51 | BACC: 100.0/61.04/59.02 | MACRO-F1: 100.0/60.26/58.01 | upd/aug time: 4.12/5.46ms | node/edge ratio: 100.18/100.43%
# Best Epoch:  269 | train/val/test | ACC: 100.0/57.35/55.86 | BACC: 100.0/54.35/52.67 | MACRO-F1: 100.0/53.61/51.94 | upd/aug time: 3.78/4.97ms | node/edge ratio: 100.18/100.46%
# Best Epoch:  126 | train/val/test | ACC: 100.0/66.50/66.42 | BACC: 100.0/60.06/60.31 | MACRO-F1: 100.0/58.12/58.61 | upd/aug time: 4.05/5.45ms | node/edge ratio: 100.18/100.54%
# Best Epoch:  177 | train/val/test | ACC: 100.0/60.44/59.81 | BACC: 100.0/54.97/54.34 | MACRO-F1: 100.0/53.60/52.80 | upd/aug time: 3.64/5.00ms | node/edge ratio: 100.18/100.53%
# Best Epoch:  143 | train/val/test | ACC: 100.0/67.80/66.60 | BACC: 100.0/61.49/60.37 | MACRO-F1: 100.0/59.19/57.74 | upd/aug time: 3.50/4.82ms | node/edge ratio: 100.18/100.52%
# Avg Test Performance (5 runs):  | ACC: 62.64 ± 1.87 | BACC: 57.34 ± 1.44 | MACRO-F1: 55.82 ± 1.27
#
# =============================== Dataset [Pubmed] ===============================
# =============== Dataset [Pubmed] - NaturalIR [50] - ToBA [dummy] ===============
# Best Epoch:  177 | train/val/test | ACC: 100.0/61.23/60.79 | BACC: 100.0/51.78/51.42 | MACRO-F1: 100.0/46.34/46.01 | upd/aug time: 5.66/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  193 | train/val/test | ACC: 100.0/57.31/58.35 | BACC: 100.0/49.05/49.97 | MACRO-F1: 100.0/44.82/45.80 | upd/aug time: 5.67/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  170 | train/val/test | ACC: 100.0/54.26/54.48 | BACC: 100.0/47.46/47.64 | MACRO-F1: 100.0/44.33/44.54 | upd/aug time: 5.65/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   85 | train/val/test | ACC: 94.83/66.01/65.94 | BACC: 65.33/55.62/55.56 | MACRO-F1: 60.10/49.24/49.20 | upd/aug time: 6.12/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  188 | train/val/test | ACC: 100.0/62.79/62.64 | BACC: 100.0/53.11/53.01 | MACRO-F1: 100.0/47.67/47.61 | upd/aug time: 5.71/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 60.44 ± 1.73 | BACC: 51.52 ± 1.20 | MACRO-F1: 46.63 ± 0.72
# =============== Dataset [Pubmed] - NaturalIR [50] - ToBA [pred] ===============
# Best Epoch:  147 | train/val/test | ACC: 98.28/64.81/64.63 | BACC: 99.33/55.46/55.31 | MACRO-F1: 88.55/51.33/51.16 | upd/aug time: 5.99/5.81ms | node/edge ratio: 100.02/102.24%
# Best Epoch:   75 | train/val/test | ACC: 98.28/48.39/49.22 | BACC: 66.67/40.64/41.32 | MACRO-F1: 64.44/32.89/33.63 | upd/aug time: 6.03/5.65ms | node/edge ratio: 100.02/101.55%
# Best Epoch:   69 | train/val/test | ACC: 81.03/63.82/63.30 | BACC: 60.00/53.82/53.38 | MACRO-F1: 48.30/47.78/47.34 | upd/aug time: 5.91/5.49ms | node/edge ratio: 100.02/102.24%
# Best Epoch:   95 | train/val/test | ACC: 94.83/67.38/67.43 | BACC: 98.00/58.31/58.42 | MACRO-F1: 93.09/55.10/55.35 | upd/aug time: 6.12/5.51ms | node/edge ratio: 100.02/101.98%
# Best Epoch:  333 | train/val/test | ACC: 98.28/64.80/64.52 | BACC: 66.67/54.59/54.35 | MACRO-F1: 66.34/48.37/48.16 | upd/aug time: 5.70/5.51ms | node/edge ratio: 100.02/102.06%
# Avg Test Performance (5 runs):  | ACC: 61.82 ± 2.88 | BACC: 52.55 ± 2.62 | MACRO-F1: 47.13 ± 3.27
# =============== Dataset [Pubmed] - NaturalIR [50] - ToBA [topo] ===============
# Best Epoch:   58 | train/val/test | ACC: 98.28/63.68/63.61 | BACC: 66.67/53.63/53.56 | MACRO-F1: 64.44/47.33/47.27 | upd/aug time: 6.01/44.43ms | node/edge ratio: 100.02/100.60%
# Best Epoch:  114 | train/val/test | ACC: 100.0/46.77/47.48 | BACC: 100.0/40.52/41.07 | MACRO-F1: 100.0/33.82/34.51 | upd/aug time: 6.16/44.82ms | node/edge ratio: 100.02/100.28%
# Best Epoch:  144 | train/val/test | ACC: 94.83/65.62/65.36 | BACC: 98.00/56.67/56.42 | MACRO-F1: 93.09/53.44/53.15 | upd/aug time: 6.20/45.02ms | node/edge ratio: 100.02/100.57%
# Best Epoch:   59 | train/val/test | ACC: 93.10/65.26/65.16 | BACC: 64.67/54.97/54.88 | MACRO-F1: 58.23/48.95/48.91 | upd/aug time: 6.24/44.78ms | node/edge ratio: 100.02/100.46%
# Best Epoch:  209 | train/val/test | ACC: 98.28/74.01/73.66 | BACC: 99.33/73.21/73.07 | MACRO-F1: 88.55/73.77/73.57 | upd/aug time: 5.72/44.24ms | node/edge ratio: 100.02/100.91%
# Avg Test Performance (5 runs):  | ACC: 63.05 ± 3.82 | BACC: 55.80 ± 4.57 | MACRO-F1: 51.48 ± 5.67
#
# //////////////////// Imbalance Type [Natural] - Ratio [100] ////////////////////
#
# ================================ Dataset [Cora] ================================
# =============== Dataset [Cora] - NaturalIR [100] - ToBA [dummy] ===============
# Best Epoch:  101 | train/val/test | ACC: 99.46/71.83/70.65 | BACC: 85.71/61.94/60.90 | MACRO-F1: 84.13/60.55/59.84 | upd/aug time: 3.92/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  245 | train/val/test | ACC: 100.0/77.78/74.21 | BACC: 100.0/70.65/66.22 | MACRO-F1: 100.0/70.47/66.60 | upd/aug time: 3.39/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  177 | train/val/test | ACC: 99.46/63.33/62.97 | BACC: 99.69/50.73/50.48 | MACRO-F1: 99.77/48.05/47.59 | upd/aug time: 3.24/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  246 | train/val/test | ACC: 99.46/67.94/68.59 | BACC: 99.69/58.30/59.41 | MACRO-F1: 99.77/57.30/58.63 | upd/aug time: 3.85/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  332 | train/val/test | ACC: 100.0/72.06/73.97 | BACC: 100.0/63.55/64.13 | MACRO-F1: 100.0/65.62/64.72 | upd/aug time: 3.27/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 70.08 ± 1.85 | BACC: 60.23 ± 2.43 | MACRO-F1: 59.48 ± 2.97
# ================ Dataset [Cora] - NaturalIR [100] - ToBA [pred] ================
# Best Epoch:  369 | train/val/test | ACC: 100.0/74.84/72.63 | BACC: 100.0/67.09/65.24 | MACRO-F1: 100.0/66.93/65.82 | upd/aug time: 3.21/3.73ms | node/edge ratio: 100.26/101.68%
# Best Epoch:  269 | train/val/test | ACC: 100.0/76.03/72.39 | BACC: 100.0/69.81/65.39 | MACRO-F1: 100.0/69.26/65.04 | upd/aug time: 3.22/3.74ms | node/edge ratio: 100.26/101.46%
# Best Epoch:  193 | train/val/test | ACC: 99.46/71.83/70.41 | BACC: 99.69/64.13/62.32 | MACRO-F1: 99.77/64.20/62.35 | upd/aug time: 3.20/3.69ms | node/edge ratio: 100.26/102.14%
# Best Epoch:  224 | train/val/test | ACC: 99.46/69.05/70.25 | BACC: 99.69/62.69/64.05 | MACRO-F1: 99.77/61.51/62.19 | upd/aug time: 3.28/3.73ms | node/edge ratio: 100.26/101.75%
# Best Epoch:  421 | train/val/test | ACC: 100.0/72.86/74.29 | BACC: 100.0/67.15/68.11 | MACRO-F1: 100.0/68.04/68.38 | upd/aug time: 3.26/3.74ms | node/edge ratio: 100.26/101.84%
# Avg Test Performance (5 runs):  | ACC: 71.99 ± 0.67 | BACC: 65.02 ± 0.85 | MACRO-F1: 64.75 ± 1.03
# ================ Dataset [Cora] - NaturalIR [100] - ToBA [topo] ================
# Best Epoch:  201 | train/val/test | ACC: 100.0/75.24/73.50 | BACC: 100.0/66.44/64.65 | MACRO-F1: 100.0/65.02/63.29 | upd/aug time: 3.20/4.28ms | node/edge ratio: 100.26/101.23%
# Best Epoch:  299 | train/val/test | ACC: 100.0/78.97/76.74 | BACC: 100.0/73.68/70.93 | MACRO-F1: 100.0/73.89/71.43 | upd/aug time: 3.73/4.83ms | node/edge ratio: 100.26/100.86%
# Best Epoch:  217 | train/val/test | ACC: 99.46/73.65/73.42 | BACC: 99.86/67.33/67.74 | MACRO-F1: 99.77/66.99/67.44 | upd/aug time: 3.44/4.51ms | node/edge ratio: 100.26/101.44%
# Best Epoch:  246 | train/val/test | ACC: 99.46/71.51/71.60 | BACC: 99.69/64.19/63.87 | MACRO-F1: 99.77/62.68/62.24 | upd/aug time: 3.55/4.70ms | node/edge ratio: 100.26/101.11%
# Best Epoch:  274 | train/val/test | ACC: 100.0/77.86/77.37 | BACC: 100.0/72.78/71.23 | MACRO-F1: 100.0/74.34/72.29 | upd/aug time: 3.52/4.66ms | node/edge ratio: 100.26/101.27%
# Avg Test Performance (5 runs):  | ACC: 74.53 ± 0.98 | BACC: 67.68 ± 1.37 | MACRO-F1: 67.34 ± 1.83
#
# ============================== Dataset [Citeseer] ==============================
# ============= Dataset [Citeseer] - NaturalIR [100] - ToBA [dummy] =============
# Best Epoch:  305 | train/val/test | ACC: 100.0/51.39/51.52 | BACC: 100.0/45.25/45.35 | MACRO-F1: 100.0/37.98/38.13 | upd/aug time: 3.62/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  188 | train/val/test | ACC: 98.16/52.78/52.59 | BACC: 91.33/47.02/46.66 | MACRO-F1: 93.02/42.15/41.45 | upd/aug time: 3.55/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  239 | train/val/test | ACC: 100.0/51.08/50.25 | BACC: 100.0/45.08/44.45 | MACRO-F1: 100.0/38.78/37.72 | upd/aug time: 3.53/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  186 | train/val/test | ACC: 98.16/52.34/53.60 | BACC: 83.00/45.95/47.04 | MACRO-F1: 79.41/38.90/39.83 | upd/aug time: 3.54/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   85 | train/val/test | ACC: 97.55/48.61/48.30 | BACC: 66.50/42.53/42.25 | MACRO-F1: 63.91/33.68/32.85 | upd/aug time: 3.56/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 51.25 ± 0.83 | BACC: 45.15 ± 0.77 | MACRO-F1: 37.99 ± 1.29
# ============== Dataset [Citeseer] - NaturalIR [100] - ToBA [pred] ==============
# Best Epoch:  363 | train/val/test | ACC: 99.39/60.63/59.91 | BACC: 83.33/54.60/54.09 | MACRO-F1: 80.00/52.56/52.42 | upd/aug time: 4.06/4.60ms | node/edge ratio: 100.18/101.95%
# Best Epoch:  489 | train/val/test | ACC: 100.0/56.20/56.69 | BACC: 100.0/51.97/51.68 | MACRO-F1: 100.0/50.95/50.44 | upd/aug time: 3.48/3.98ms | node/edge ratio: 100.18/102.89%
# Best Epoch:  363 | train/val/test | ACC: 100.0/60.63/59.53 | BACC: 100.0/55.53/54.20 | MACRO-F1: 100.0/54.36/52.84 | upd/aug time: 3.90/4.50ms | node/edge ratio: 100.18/102.64%
# Best Epoch:  169 | train/val/test | ACC: 100.0/61.71/60.35 | BACC: 100.0/55.79/54.31 | MACRO-F1: 100.0/53.81/51.97 | upd/aug time: 3.69/4.23ms | node/edge ratio: 100.18/102.43%
# Best Epoch:  190 | train/val/test | ACC: 98.77/64.94/62.88 | BACC: 99.67/58.89/56.67 | MACRO-F1: 94.07/57.09/54.43 | upd/aug time: 3.45/3.99ms | node/edge ratio: 100.18/103.18%
# Avg Test Performance (5 runs):  | ACC: 59.87 ± 0.88 | BACC: 54.19 ± 0.71 | MACRO-F1: 52.42 ± 0.58
# ============== Dataset [Citeseer] - NaturalIR [100] - ToBA [topo] ==============
# Best Epoch:  504 | train/val/test | ACC: 100.0/65.32/65.85 | BACC: 100.0/59.92/60.54 | MACRO-F1: 100.0/58.87/59.64 | upd/aug time: 3.47/4.80ms | node/edge ratio: 100.18/100.44%
# Best Epoch:  231 | train/val/test | ACC: 100.0/61.27/61.99 | BACC: 100.0/56.38/56.86 | MACRO-F1: 100.0/55.07/55.56 | upd/aug time: 4.08/5.54ms | node/edge ratio: 100.18/100.72%
# Best Epoch:  213 | train/val/test | ACC: 100.0/60.63/60.29 | BACC: 100.0/54.55/54.44 | MACRO-F1: 100.0/51.27/51.57 | upd/aug time: 3.50/4.82ms | node/edge ratio: 100.18/100.57%
# Best Epoch:  549 | train/val/test | ACC: 100.0/66.84/67.30 | BACC: 100.0/60.53/61.15 | MACRO-F1: 100.0/58.73/59.46 | upd/aug time: 3.48/4.84ms | node/edge ratio: 100.18/100.57%
# Best Epoch:  579 | train/val/test | ACC: 99.39/65.44/64.02 | BACC: 83.33/59.19/57.73 | MACRO-F1: 83.25/56.75/55.01 | upd/aug time: 3.49/4.76ms | node/edge ratio: 100.18/100.81%
# Avg Test Performance (5 runs):  | ACC: 63.89 ± 1.13 | BACC: 58.14 ± 1.10 | MACRO-F1: 56.25 ± 1.35
#
# =============================== Dataset [Pubmed] ===============================
# ============== Dataset [Pubmed] - NaturalIR [100] - ToBA [dummy] ==============
# Best Epoch:  168 | train/val/test | ACC: 99.10/63.51/63.64 | BACC: 66.67/53.52/53.63 | MACRO-F1: 65.08/47.16/47.27 | upd/aug time: 5.68/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  161 | train/val/test | ACC: 100.0/53.63/54.91 | BACC: 100.0/45.23/46.28 | MACRO-F1: 100.0/38.92/40.00 | upd/aug time: 5.89/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   88 | train/val/test | ACC: 99.10/57.10/57.00 | BACC: 66.67/48.09/48.00 | MACRO-F1: 65.08/41.77/41.71 | upd/aug time: 5.73/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:   95 | train/val/test | ACC: 99.10/60.80/60.87 | BACC: 66.67/51.23/51.28 | MACRO-F1: 65.08/45.35/45.38 | upd/aug time: 5.69/0.00ms | node/edge ratio: 100.00/100.00%
# Best Epoch:  148 | train/val/test | ACC: 99.10/61.61/60.70 | BACC: 66.67/51.92/51.15 | MACRO-F1: 65.08/46.16/45.40 | upd/aug time: 5.69/0.00ms | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | ACC: 59.42 ± 1.38 | BACC: 50.07 ± 1.16 | MACRO-F1: 43.95 ± 1.20
# =============== Dataset [Pubmed] - NaturalIR [100] - ToBA [pred] ===============
# Best Epoch:   99 | train/val/test | ACC: 98.20/67.24/67.06 | BACC: 66.33/56.70/56.54 | MACRO-F1: 63.47/50.18/50.03 | upd/aug time: 6.17/5.99ms | node/edge ratio: 100.02/102.47%
# Best Epoch:  102 | train/val/test | ACC: 97.30/58.75/59.76 | BACC: 66.00/49.50/50.35 | MACRO-F1: 61.98/43.25/44.05 | upd/aug time: 6.20/6.09ms | node/edge ratio: 100.02/101.93%
# Best Epoch:  190 | train/val/test | ACC: 96.40/67.63/67.93 | BACC: 65.67/57.02/57.27 | MACRO-F1: 60.60/50.57/50.78 | upd/aug time: 6.12/5.97ms | node/edge ratio: 100.02/102.35%
# Best Epoch:   89 | train/val/test | ACC: 99.10/56.43/56.31 | BACC: 66.67/47.55/47.44 | MACRO-F1: 65.08/41.68/41.45 | upd/aug time: 6.21/6.09ms | node/edge ratio: 100.02/102.21%
# Best Epoch:   91 | train/val/test | ACC: 98.20/66.06/65.54 | BACC: 66.33/55.70/55.26 | MACRO-F1: 64.75/49.30/48.88 | upd/aug time: 6.22/6.10ms | node/edge ratio: 100.02/102.37%
# Avg Test Performance (5 runs):  | ACC: 63.32 ± 2.02 | BACC: 53.37 ± 1.71 | MACRO-F1: 47.04 ± 1.63
# =============== Dataset [Pubmed] - NaturalIR [100] - ToBA [topo] ===============
# Best Epoch:  123 | train/val/test | ACC: 97.30/66.85/66.54 | BACC: 66.00/56.36/56.10 | MACRO-F1: 61.98/49.81/49.58 | upd/aug time: 5.84/44.26ms | node/edge ratio: 100.02/100.82%
# Best Epoch:  202 | train/val/test | ACC: 100.0/47.23/47.75 | BACC: 100.0/40.59/41.01 | MACRO-F1: 100.0/33.65/34.16 | upd/aug time: 6.20/44.75ms | node/edge ratio: 100.02/100.32%
# Best Epoch:  222 | train/val/test | ACC: 97.30/68.02/68.14 | BACC: 99.00/58.09/58.25 | MACRO-F1: 95.14/53.23/53.53 | upd/aug time: 6.24/44.84ms | node/edge ratio: 100.02/100.57%
# Best Epoch:   89 | train/val/test | ACC: 85.59/65.96/65.49 | BACC: 61.67/55.62/55.23 | MACRO-F1: 49.15/48.99/48.66 | upd/aug time: 5.77/44.23ms | node/edge ratio: 100.02/100.56%
# Best Epoch:  255 | train/val/test | ACC: 99.10/66.66/66.30 | BACC: 66.67/56.35/56.06 | MACRO-F1: 66.50/50.58/50.39 | upd/aug time: 5.73/44.22ms | node/edge ratio: 100.02/100.77%
# Avg Test Performance (5 runs):  | ACC: 62.84 ± 3.40 | BACC: 53.33 ± 2.79 | MACRO-F1: 47.26 ± 3.02
